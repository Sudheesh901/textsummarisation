# %%
d={"key":"value","key1":"value1"}

# %%
d['key']
# Out:
# 'value'

# %%
d.key
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 d.key
#
# AttributeError: 'dict' object has no attribute 'key'

# %% [markdown]
# USe configBox

# %%
from box import ConfigBox

# %%
d2=ConfigBox({"key":"value","key1":"value1"})

# %%
d2.key
# Out:
# 'value'

# %%
# why @ensure_annotation decorator

# %%
def get_product(x:int,y:int) ->int:
    return x*y

# %%
get_product(x=3,y=2)
# Out:
# 6

# %%
get_product(x=4,y="2")
# Out:
# '2222'

# %% [markdown]
# IT is returnig string instead of int

# %%
from typeguard import typechecked

# %%
from textSummarizer.utils.common import get_product

print(get_product(3,4))

print(get_product(4,"5"))
# Out:
# 12
# ---------------------------------------------------------------------------
# TypeCheckError                            Traceback (most recent call last)
# Cell In[16], line 5
#       1 from textSummarizer.utils.common import get_product
#       3 print(get_product(3,4))
# ----> 5 print(get_product(4,"5"))
#
# File D:\End_to_End\textsummarisation\src\textSummarizer\utils\common.py:62, in get_product(x, y)
#      57     return f"~{size_in_kb} KB"
#      60 #this is just to check in .ipynb file as typecheked donot work in .ipynb file
#      61 @typechecked
# ---> 62 def get_product(x: int, y: int) -> int:
#      63     return x * y
#
# File d:\End_to_End\textsummarisation\venv\Lib\site-packages\typeguard\_functions.py:137, in check_argument_types(func_name, arguments, memo)
#     134         raise exc
#     136 try:
# --> 137     check_type_internal(value, annotation, memo)
#     138 except TypeCheckError as exc:
# ...
